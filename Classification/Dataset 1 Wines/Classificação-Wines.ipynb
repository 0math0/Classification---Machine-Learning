# %% [markdown]
# # Classificação
#
# Conjunto de dados de 13 quantidades constituintes de 3 tipos diferentes de vinhos.
#
# Atributos:
#
#     1) Alcohol
#     2) Malic acid
#     3) Ash
#     4) Alcalinity of ash
#     5) Magnesium
#     6) Total phenols
#     7) Flavanoids
#     8) Nonflavanoid phenols
#     9) Proanthocyanins
#     10) Color intensity
#     11) Hue
#     12) OD280/OD315 of diluted wines
#     13) Proline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_curve,auc
from sklearn.metrics import roc_auc_score 
from sklearn.preprocessing import LabelBinarizer
from scipy import interp
from itertools import cycle
from sklearn import metrics

# %%
dataset = pd.read_csv('wine.data.txt')

# %%
#Nomeando colunas
data = pd.DataFrame(dataset)
data.columns =["Class","Alcohol","Malic Acid","Ash","Alcalinity of ash","Magnesium","Total phenols","Flavanoids","Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/0D315 of diluted wines","Proline"]

# %% [markdown]
# # Estatísticas: (Contagem de dados, média, desvio padrão, mínimo, 25%, 50%, 75% e máximo):

# %%
data.describe()
# Out:
#             Class     Alcohol  Malic Acid         Ash  Alcalinity of ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.740000    1.200000              0.270000
# 50%     98.000000       2.350000    2.130000              0.340000
# 75%    107.000000       2.800000    2.860000              0.440000
# max    162.000000       3.880000    5.080000              0.660000
#
#        Proanthocyanins  Color intensity         Hue  \
# count       177.000000       177.000000  177.000000
# mean          1.586949         5.054802    0.956983
# std           0.571545         2.324446    0.229135
# min           0.410000         1.280000    0.480000
# 25%           1.250000         3.210000    0.780000
# 50%           1.550000         4.680000    0.960000
# 75%           1.950000         6.200000    1.120000
# max           3.580000        13.000000    1.710000
#
#        OD280/0D315 of diluted wines      Proline
# count                    177.000000   177.000000
# mean                       2.604294   745.096045
# std                        0.705103   314.884046
# min                        1.270000   278.000000
# 25%                        1.930000   500.000000
# 50%                        2.780000   672.000000
# 75%                        3.170000   985.000000
# max                        4.000000  1680.000000

# %%
#correlação
data.corr()
# Out:
#                                  Class   Alcohol  Malic Acid       Ash  \
# Class                         1.000000 -0.321238    0.436127 -0.048260
# Alcohol                      -0.321238  1.000000    0.099963  0.210964
# Malic Acid                    0.436127  0.099963    1.000000  0.164955
# Ash                          -0.048260  0.210964    0.164955  1.000000
# Alcalinity of ash             0.513963 -0.303350    0.286148  0.446698
# Magnesium                    -0.198944  0.258742   -0.049049  0.287107
# Total phenols                -0.717933  0.284543   -0.333512  0.128176
# Flavanoids                   -0.846485  0.230133   -0.409324  0.114084
# Nonflavanoid phenols          0.487215 -0.151445    0.291501  0.187354
# Proanthocyanins              -0.494887  0.127561   -0.217975  0.008082
# Color intensity               0.268562  0.547883    0.250053  0.258643
# Hue                          -0.617690 -0.075375   -0.560854 -0.075181
# OD280/0D315 of diluted wines -0.786428  0.057417   -0.366720  0.001503
# Proline                      -0.631227  0.641068   -0.189512  0.222979
#
#                               Alcalinity of ash  Magnesium  Total phenols  \
# Class                                  0.513963  -0.198944      -0.717933
# Alcohol                               -0.303350   0.258742       0.284543
# Malic Acid                             0.286148  -0.049049      -0.333512
# Ash                                    0.446698   0.287107       0.128176
# Alcalinity of ash                      1.000000  -0.071707      -0.317583
# Magnesium                             -0.071707   1.000000       0.208200
# Total phenols                         -0.317583   0.208200       1.000000
# Flavanoids                            -0.346922   0.187101       0.864046
# Nonflavanoid phenols                   0.359395  -0.252091      -0.448301
# Proanthocyanins                       -0.190779   0.226504       0.610533
# Color intensity                        0.020478   0.199337      -0.056401
# Hue                                   -0.272719   0.052042       0.432987
# OD280/0D315 of diluted wines          -0.268186   0.046961       0.699566
# Proline                               -0.436858   0.387542       0.495839
#
#                               Flavanoids  Nonflavanoid phenols  \
# Class                          -0.846485              0.487215
# Alcohol                         0.230133             -0.151445
# Malic Acid                     -0.409324              0.291501
# Ash                             0.114084              0.187354
# Alcalinity of ash              -0.346922              0.359395
# Magnesium                       0.187101             -0.252091
# Total phenols                   0.864046             -0.448301
# Flavanoids                      1.000000             -0.536326
# Nonflavanoid phenols           -0.536326              1.000000
# Proanthocyanins                 0.650254             -0.363268
# Color intensity                -0.174411              0.140192
# Hue                             0.543208             -0.261709
# OD280/0D315 of diluted wines    0.786372             -0.501859
# Proline                         0.491180             -0.308886
#
#                               Proanthocyanins  Color intensity       Hue  \
# Class                               -0.494887         0.268562 -0.617690
# Alcohol                              0.127561         0.547883 -0.075375
# Malic Acid                          -0.217975         0.250053 -0.560854
# Ash                                  0.008082         0.258643 -0.075181
# Alcalinity of ash                   -0.190779         0.020478 -0.272719
# Magnesium                            0.226504         0.199337  0.052042
# Total phenols                        0.610533        -0.056401  0.432987
# Flavanoids                           0.650254        -0.174411  0.543208
# Nonflavanoid phenols                -0.363268         0.140192 -0.261709
# Proanthocyanins                      1.000000        -0.027112  0.294397
# Color intensity                     -0.027112         1.000000 -0.522615
# Hue                                  0.294397        -0.522615  1.000000
# OD280/0D315 of diluted wines         0.513415        -0.435744  0.567395
# Proline                              0.325731         0.315632  0.234879
#
#                               OD280/0D315 of diluted wines   Proline
# Class                                            -0.786428 -0.631227
# Alcohol                                           0.057417  0.641068
# Malic Acid                                       -0.366720 -0.189512
# Ash                                               0.001503  0.222979
# Alcalinity of ash                                -0.268186 -0.436858
# Magnesium                                         0.046961  0.387542
# Total phenols                                     0.699566  0.495839
# Flavanoids                                        0.786372  0.491180
# Nonflavanoid phenols                             -0.501859 -0.308886
# Proanthocyanins                                   0.513415  0.325731
# Color intensity                                  -0.435744  0.315632
# Hue                                               0.567395  0.234879
# OD280/0D315 of diluted wines                      1.000000  0.306031
# Proline                                           0.306031  1.000000

# %% [markdown]
# # Visualização:

# %%
#boxplot
boxplot = data.boxplot()

# %%
#correlograma
sns.pairplot(data)
plt.show()

# %%
#Correlação:
sns.heatmap(data.corr())

# %% [markdown]
# # Classificação:

# %%
# Organizando vetores para data e classes: X - features, y - labels
n_classes=3
X = np.array(data.drop(['Class'], axis=1))
y = np.array(data['Class'])

# %%
# Dividindo os dados em um conjunto de teste e treino
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# C-Support Vector Classification
kernels = ['linear', 'rbf', 'poly']
for kernel in kernels:
    gammas = [0.1, 1, 10]

    for gamma in gammas:
        cs = [0.1, 1, 10]

        for c in cs:
            svc = SVC(kernel=kernel, gamma=gamma, C=c)
            model_svc = svc.fit(X_train, y_train)
            preds_svc = model_svc.predict(X_test)
            print("SVC: ",accuracy_score(y_test, preds_svc),"com",kernel,"kernel, com", gamma, "gamma e com",c,"c.")
# Out:
# SVC:  0.9491525423728814 com linear kernel, com 0.1 gamma e com 0.1 c.
# SVC:  0.9491525423728814 com linear kernel, com 0.1 gamma e com 1 c.
# SVC:  0.9491525423728814 com linear kernel, com 0.1 gamma e com 10 c.
# SVC:  0.9491525423728814 com linear kernel, com 1 gamma e com 0.1 c.
# SVC:  0.9491525423728814 com linear kernel, com 1 gamma e com 1 c.
# SVC:  0.9491525423728814 com linear kernel, com 1 gamma e com 10 c.
# SVC:  0.9491525423728814 com linear kernel, com 10 gamma e com 0.1 c.
# SVC:  0.9491525423728814 com linear kernel, com 10 gamma e com 1 c.
# SVC:  0.9491525423728814 com linear kernel, com 10 gamma e com 10 c.
# SVC:  0.423728813559322 com rbf kernel, com 0.1 gamma e com 0.1 c.
# SVC:  0.4406779661016949 com rbf kernel, com 0.1 gamma e com 1 c.
# SVC:  0.4576271186440678 com rbf kernel, com 0.1 gamma e com 10 c.
# SVC:  0.423728813559322 com rbf kernel, com 1 gamma e com 0.1 c.
# SVC:  0.423728813559322 com rbf kernel, com 1 gamma e com 1 c.
# SVC:  0.423728813559322 com rbf kernel, com 1 gamma e com 10 c.
# SVC:  0.423728813559322 com rbf kernel, com 10 gamma e com 0.1 c.
# SVC:  0.423728813559322 com rbf kernel, com 10 gamma e com 1 c.
# SVC:  0.423728813559322 com rbf kernel, com 10 gamma e com 10 c.
# SVC:  0.9152542372881356 com poly kernel, com 0.1 gamma e com 0.1 c.
# SVC:  0.9152542372881356 com poly kernel, com 0.1 gamma e com 1 c.
# SVC:  0.9152542372881356 com poly kernel, com 0.1 gamma e com 10 c.
# SVC:  0.9152542372881356 com poly kernel, com 1 gamma e com 0.1 c.
# SVC:  0.9152542372881356 com poly kernel, com 1 gamma e com 1 c.
# SVC:  0.9152542372881356 com poly kernel, com 1 gamma e com 10 c.
# SVC:  0.9152542372881356 com poly kernel, com 10 gamma e com 0.1 c.
# SVC:  0.9152542372881356 com poly kernel, com 10 gamma e com 1 c.
# SVC:  0.9152542372881356 com poly kernel, com 10 gamma e com 10 c.

# %%
# Testando o melhor valor de K para KNN
for i in range(1,30):
    knn = KNeighborsClassifier(n_neighbors=i,metric='euclidean')
    model_knn = knn.fit(X_train, y_train)
    preds_knn = model_knn.predict(X_test)
    print("K Neighbors Classifier: ",accuracy_score(y_test, preds_knn),"com",i,"vizinhos.")
# Out:
# K Neighbors Classifier:  0.711864406779661 com 1 vizinhos.
# K Neighbors Classifier:  0.6949152542372882 com 2 vizinhos.
# K Neighbors Classifier:  0.6779661016949152 com 3 vizinhos.
# K Neighbors Classifier:  0.6949152542372882 com 4 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 5 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 6 vizinhos.
# K Neighbors Classifier:  0.7288135593220338 com 7 vizinhos.
# K Neighbors Classifier:  0.7288135593220338 com 8 vizinhos.
# K Neighbors Classifier:  0.7288135593220338 com 9 vizinhos.
# K Neighbors Classifier:  0.6949152542372882 com 10 vizinhos.
# K Neighbors Classifier:  0.6949152542372882 com 11 vizinhos.
# K Neighbors Classifier:  0.6949152542372882 com 12 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 13 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 14 vizinhos.
# K Neighbors Classifier:  0.7288135593220338 com 15 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 16 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 17 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 18 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 19 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 20 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 21 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 22 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 23 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 24 vizinhos.
# K Neighbors Classifier:  0.711864406779661 com 25 vizinhos.
# K Neighbors Classifier:  0.6949152542372882 com 26 vizinhos.
# K Neighbors Classifier:  0.6949152542372882 com 27 vizinhos.
# K Neighbors Classifier:  0.6949152542372882 com 28 vizinhos.
# K Neighbors Classifier:  0.6949152542372882 com 29 vizinhos.

# %%
# Testando a melhores parâmetros da árvore de decisão
# Gini index
for i in range(1,6):
    dtc = DecisionTreeClassifier(criterion = "gini", random_state = 100, max_depth=i, min_samples_leaf=5)
    model_dtc = dtc.fit(X_train, y_train)
    preds_dtc = model_dtc.predict(X_test)
    print("Decision Tree Classifier: ",accuracy_score(y_test, preds_dtc),"com",i,"profundidade.")
# Out:
# Decision Tree Classifier:  0.559322033898305 com 1 profundidade.
# Decision Tree Classifier:  0.9152542372881356 com 2 profundidade.
# Decision Tree Classifier:  0.8983050847457628 com 3 profundidade.
# Decision Tree Classifier:  0.8983050847457628 com 4 profundidade.
# Decision Tree Classifier:  0.8983050847457628 com 5 profundidade.

# %%
# Gain information
for i in range(1,6):
    dtc = DecisionTreeClassifier(criterion = "entropy", random_state = 100, max_depth=i, min_samples_leaf=5)
    model_dtc = dtc.fit(X_train, y_train)
    preds_dtc = model_dtc.predict(X_test)
    print("Decision Tree Classifier: ",accuracy_score(y_test, preds_dtc),"com",i,"profundidade.")
# Out:
# Decision Tree Classifier:  0.559322033898305 com 1 profundidade.
# Decision Tree Classifier:  0.9152542372881356 com 2 profundidade.
# Decision Tree Classifier:  0.8983050847457628 com 3 profundidade.
# Decision Tree Classifier:  0.8983050847457628 com 4 profundidade.
# Decision Tree Classifier:  0.8983050847457628 com 5 profundidade.

# %%
# Inicializando os classificadores
lr = LogisticRegression()
gnb = GaussianNB()
svc = SVC(kernel='linear')
knn = KNeighborsClassifier(n_neighbors=7,metric='euclidean')
dtc = DecisionTreeClassifier(criterion = "entropy", random_state = 100, max_depth=2, min_samples_leaf=5)

# %%
# Treinar os classificadores
model_lr = lr.fit(X_train, y_train)
model_gnb = gnb.fit(X_train, y_train)
model_svc = svc.fit(X_train, y_train)
model_knn = knn.fit(X_train, y_train)
model_dtc = dtc.fit(X_train, y_train)
# Out:
# C:\Users\mathe\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mathe\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
# Fazer previsões para ter uma ideia do que o modelo determinou
preds_lr = model_lr.predict(X_test)
print("Logistic Regression: ",preds_lr)
preds_gnb = model_gnb.predict(X_test)
print("Gaussian: ",preds_gnb)
preds_svc = model_svc.predict(X_test)
print("SVC: ",preds_svc)
preds_knn = model_knn.predict(X_test)
print("K Neighbors Classifier: ",preds_knn)
preds_dtc = model_dtc.predict(X_test)
print("Decision Tree Classifier: ",preds_dtc)
# Out:
# Logistic Regression:  [1 1 3 1 2 1 2 3 2 3 2 3 1 2 1 2 2 3 1 2 1 2 3 3 3 3 2 2 2 1 1 2 3 1 1 1 3
#  3 2 3 1 2 2 2 3 1 2 2 3 1 2 1 1 3 2 2 2 1 2]
# Gaussian:  [1 1 3 1 2 1 2 3 2 3 2 3 1 2 1 2 2 3 1 2 1 2 2 3 3 3 2 2 2 1 1 2 3 1 1 1 3
#  3 2 3 1 2 2 2 3 1 2 2 3 1 2 1 1 3 2 2 2 1 2]
# SVC:  [1 1 3 1 2 1 2 3 2 3 2 3 1 2 1 2 2 3 1 2 1 2 3 3 3 3 2 2 2 1 1 2 3 1 1 1 3
#  3 2 3 1 2 2 2 3 1 2 2 3 1 2 1 1 3 2 2 2 1 2]
# K Neighbors Classifier:  [1 1 3 1 3 1 3 3 3 1 1 3 1 3 1 3 2 3 1 2 1 2 2 3 2 2 2 2 2 1 1 2 1 1 1 3 1
#  3 2 3 1 2 2 3 3 1 3 2 3 1 3 1 1 3 3 2 2 1 2]
# Decision Tree Classifier:  [1 1 2 1 2 1 2 3 2 1 1 3 1 2 1 2 2 3 1 2 1 2 3 3 3 3 2 2 2 1 1 2 3 1 1 2 3
#  3 2 3 1 2 2 2 3 1 2 2 3 1 2 1 1 3 2 2 2 1 2]

# %% [markdown]
# # Validações:

# %%
# Avaliar a acurácia
print("Logistic Regression: ",accuracy_score(y_test, preds_lr))
print("Gaussian: ",accuracy_score(y_test, preds_gnb))
print("SVC: ",accuracy_score(y_test, preds_svc))
print("K Neighbors Classifier: ",accuracy_score(y_test, preds_knn))
print("Decision Tree Classifier: ",accuracy_score(y_test, preds_dtc))
# Out:
# Logistic Regression:  0.9491525423728814
# Gaussian:  0.9661016949152542
# SVC:  0.9491525423728814
# K Neighbors Classifier:  0.7288135593220338
# Decision Tree Classifier:  0.9152542372881356

# %%
#Criando as matrizes de confusões
print("Logistic Regression: ")
cm_lr = confusion_matrix(y_test, preds_lr)
sns.heatmap(cm_lr, annot=True)
# Out:
# Logistic Regression:

# %%
print("Gaussian: ")
cm_gnb = confusion_matrix(y_test, preds_gnb)
sns.heatmap(cm_gnb, annot=True)
# Out:
# Gaussian:

# %%
print("SVC: ")
cm_svc = confusion_matrix(y_test, preds_svc)
sns.heatmap(cm_svc, annot=True)
# Out:
# SVC:

# %%
print("K Neighbors Classifier: ")
cm_knn = confusion_matrix(y_test, preds_knn)
sns.heatmap(cm_knn, annot=True)
# Out:
# K Neighbors Classifier:

# %%
print("Decision Tree Classifier: ")
cm_dtc = confusion_matrix(y_test, preds_dtc)
sns.heatmap(cm_dtc, annot=True)
# Out:
# Decision Tree Classifier:

# %%
#Utilizando a matriz de confusão para medir a acurácia
acertos=0
for i in range (3): 
    acertos = acertos + cm_lr[i][i]
acur = acertos/len(y_test)
print("Logistic Regression: " ,acur)

acertos=0
for i in range (3): 
    acertos = acertos + cm_gnb[i][i]
acur = acertos/len(y_test)
print("Gaussian: " ,acur)

acertos=0
for i in range (3): 
    acertos = acertos + cm_svc[i][i]
acur = acertos/len(y_test)
print("SVC: " ,acur)

acertos=0
for i in range (3): 
    acertos = acertos + cm_knn[i][i]
acur = acertos/len(y_test)
print("K Neighbors Classifier: " ,acur)

acertos=0
for i in range (3): 
    acertos = acertos + cm_dtc[i][i]
acur = acertos/len(y_test)
print("Decision Tree Classifier: " ,acur)
# Out:
# Logistic Regression:  0.9491525423728814
# Gaussian:  0.9661016949152542
# SVC:  0.9491525423728814
# K Neighbors Classifier:  0.7288135593220338
# Decision Tree Classifier:  0.9152542372881356

# %%
# Precisão, recall e f-measure (com micro, macro e weighted average)
print("Logistic Regression: ")
target_names = ['Class 1', 'Class 2', 'Class 3']
print(classification_report(y_test, preds_lr, target_names=target_names))
print("Gaussian: ")
print(classification_report(y_test, preds_gnb, target_names=target_names))
print("SVC: ")
print(classification_report(y_test, preds_svc, target_names=target_names))
print("K Neighbors Classifier: ")
print(classification_report(y_test, preds_knn, target_names=target_names))
print("Decision Tree Classifier: ")
print(classification_report(y_test, preds_dtc, target_names=target_names))
# Out:
# Logistic Regression:
#               precision    recall  f1-score   support
#
#      Class 1       1.00      0.95      0.97        20
#      Class 2       0.96      0.92      0.94        25
#      Class 3       0.88      1.00      0.93        14
#
#    micro avg       0.95      0.95      0.95        59
#    macro avg       0.94      0.96      0.95        59
# weighted avg       0.95      0.95      0.95        59
#
# Gaussian:
#               precision    recall  f1-score   support
#
#      Class 1       1.00      0.95      0.97        20
#      Class 2       0.96      0.96      0.96        25
#      Class 3       0.93      1.00      0.97        14
#
#    micro avg       0.97      0.97      0.97        59
#    macro avg       0.96      0.97      0.97        59
# weighted avg       0.97      0.97      0.97        59
#
# SVC:
#               precision    recall  f1-score   support
#
#      Class 1       1.00      0.95      0.97        20
#      Class 2       0.96      0.92      0.94        25
#      Class 3       0.88      1.00      0.93        14
#
#    micro avg       0.95      0.95      0.95        59
#    macro avg       0.94      0.96      0.95        59
# weighted avg       0.95      0.95      0.95        59
#
# K Neighbors Classifier:
#               precision    recall  f1-score   support
#
#      Class 1       0.86      0.95      0.90        20
#      Class 2       0.88      0.60      0.71        25
#      Class 3       0.45      0.64      0.53        14
#
#    micro avg       0.73      0.73      0.73        59
#    macro avg       0.73      0.73      0.72        59
# weighted avg       0.77      0.73      0.73        59
#
# Decision Tree Classifier:
#               precision    recall  f1-score   support
#
#      Class 1       0.95      0.95      0.95        20
#      Class 2       0.92      0.92      0.92        25
#      Class 3       0.86      0.86      0.86        14
#
#    micro avg       0.92      0.92      0.92        59
#    macro avg       0.91      0.91      0.91        59
# weighted avg       0.92      0.92      0.92        59

# %%
#Índice Kappa
print("Logistic Regression: ")
print(cohen_kappa_score(y_test, preds_lr),"\n")
print("Gaussian: ")
print(cohen_kappa_score(y_test, preds_gnb),"\n")
print("SVC: ")
print(cohen_kappa_score(y_test, preds_svc),"\n")
print("K Neighbors Classifier: ")
print(cohen_kappa_score(y_test, preds_knn),"\n")
print("Decision Tree Classifier: ")
print(cohen_kappa_score(y_test, preds_dtc),"\n")
# Out:
# Logistic Regression:
# 0.922266139657444
#
# Gaussian:
# 0.9479258605472198
#
# SVC:
# 0.922266139657444
#
# K Neighbors Classifier:
# 0.595890410958904
#
# Decision Tree Classifier:
# 0.8694690265486725

# %%
#Curva ROC

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_lr))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Logistic Regression - WINE DATASET')
plt.legend(loc="lower right")
plt.show()

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_gnb))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for GaussianNB - WINE DATASET')
plt.legend(loc="lower right")
plt.show()

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_svc))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for SVC - WINE DATASET')
plt.legend(loc="lower right")
plt.show()

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_knn))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for K Neighbors Classifier - WINE DATASET')
plt.legend(loc="lower right")
plt.show()

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_dtc))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Decision Tree Classifier - WINE DATASET')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Utilizando somente os atributos: Malic Acid, alcalinity of ash, nonflavanoid phenols e color intensity

# %%
#novo dataset
data_red = data

# %%
#removendo os atributos indesejados
data_red = data_red.drop(["Alcohol","Ash","Magnesium","Total phenols","Flavanoids","Proanthocyanins","Hue","OD280/0D315 of diluted wines","Proline"], axis=1)

# %%
# Organizando vetores para data e classes: X - features, y - labels
X = np.array(data_red.drop(['Class'], axis=1))
y = np.array(data_red['Class'])

# %%
# Dividindo os dados em um conjunto de teste e treino
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# C-Support Vector Classification
kernels = ['linear', 'rbf', 'poly']
for kernel in kernels:
    gammas = [0.1, 1]

    for gamma in gammas:
        cs = [0.1, 1, 10]

        for c in cs:
            svc = SVC(kernel=kernel, gamma=gamma, C=c)
            model_svc = svc.fit(X_train, y_train)
            preds_svc = model_svc.predict(X_test)
            print("SVC: ",accuracy_score(y_test, preds_svc),"com",kernel,"kernel, com", gamma, "gamma e com",c,"c.")
# Out:
# SVC:  0.8135593220338984 com linear kernel, com 0.1 gamma e com 0.1 c.
# SVC:  0.7966101694915254 com linear kernel, com 0.1 gamma e com 1 c.
# SVC:  0.864406779661017 com linear kernel, com 0.1 gamma e com 10 c.
# SVC:  0.8135593220338984 com linear kernel, com 1 gamma e com 0.1 c.
# SVC:  0.7966101694915254 com linear kernel, com 1 gamma e com 1 c.
# SVC:  0.864406779661017 com linear kernel, com 1 gamma e com 10 c.
# SVC:  0.8135593220338984 com rbf kernel, com 0.1 gamma e com 0.1 c.
# SVC:  0.7627118644067796 com rbf kernel, com 0.1 gamma e com 1 c.
# SVC:  0.8135593220338984 com rbf kernel, com 0.1 gamma e com 10 c.
# SVC:  0.423728813559322 com rbf kernel, com 1 gamma e com 0.1 c.
# SVC:  0.7627118644067796 com rbf kernel, com 1 gamma e com 1 c.
# SVC:  0.7796610169491526 com rbf kernel, com 1 gamma e com 10 c.
# SVC:  0.8813559322033898 com poly kernel, com 0.1 gamma e com 0.1 c.
# SVC:  0.8305084745762712 com poly kernel, com 0.1 gamma e com 1 c.
# SVC:  0.9152542372881356 com poly kernel, com 0.1 gamma e com 10 c.
# SVC:  0.8983050847457628 com poly kernel, com 1 gamma e com 0.1 c.
# SVC:  0.7966101694915254 com poly kernel, com 1 gamma e com 1 c.
# SVC:  0.7966101694915254 com poly kernel, com 1 gamma e com 10 c.

# %%
# Testando o melhor valor de K para KNN
for i in range(1,30):
    knn = KNeighborsClassifier(n_neighbors=i,metric='euclidean')
    model_knn = knn.fit(X_train, y_train)
    preds_knn = model_knn.predict(X_test)
    print("K Neighbors Classifier: ",accuracy_score(y_test, preds_knn),"com",i,"vizinhos.")
# Out:
# K Neighbors Classifier:  0.7796610169491526 com 1 vizinhos.
# K Neighbors Classifier:  0.7457627118644068 com 2 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 3 vizinhos.
# K Neighbors Classifier:  0.7796610169491526 com 4 vizinhos.
# K Neighbors Classifier:  0.7966101694915254 com 5 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 6 vizinhos.
# K Neighbors Classifier:  0.7966101694915254 com 7 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 8 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 9 vizinhos.
# K Neighbors Classifier:  0.7966101694915254 com 10 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 11 vizinhos.
# K Neighbors Classifier:  0.8305084745762712 com 12 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 13 vizinhos.
# K Neighbors Classifier:  0.8305084745762712 com 14 vizinhos.
# K Neighbors Classifier:  0.8305084745762712 com 15 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 16 vizinhos.
# K Neighbors Classifier:  0.7966101694915254 com 17 vizinhos.
# K Neighbors Classifier:  0.7966101694915254 com 18 vizinhos.
# K Neighbors Classifier:  0.7796610169491526 com 19 vizinhos.
# K Neighbors Classifier:  0.7796610169491526 com 20 vizinhos.
# K Neighbors Classifier:  0.7627118644067796 com 21 vizinhos.
# K Neighbors Classifier:  0.7627118644067796 com 22 vizinhos.
# K Neighbors Classifier:  0.7966101694915254 com 23 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 24 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 25 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 26 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 27 vizinhos.
# K Neighbors Classifier:  0.8135593220338984 com 28 vizinhos.
# K Neighbors Classifier:  0.7966101694915254 com 29 vizinhos.

# %%
# Testando a melhores parâmetros da árvore de decisão
# Gini index
for i in range(1,6):
    dtc = DecisionTreeClassifier(criterion = "gini", random_state = 100, max_depth=i, min_samples_leaf=5)
    model_dtc = dtc.fit(X_train, y_train)
    preds_dtc = model_dtc.predict(X_test)
    print("Decision Tree Classifier: ",accuracy_score(y_test, preds_dtc),"com",i,"profundidade.")
# Out:
# Decision Tree Classifier:  0.6610169491525424 com 1 profundidade.
# Decision Tree Classifier:  0.7796610169491526 com 2 profundidade.
# Decision Tree Classifier:  0.7796610169491526 com 3 profundidade.
# Decision Tree Classifier:  0.7627118644067796 com 4 profundidade.
# Decision Tree Classifier:  0.7627118644067796 com 5 profundidade.

# %%
# Gain information
for i in range(1,6):
    dtc = DecisionTreeClassifier(criterion = "entropy", random_state = 100, max_depth=i, min_samples_leaf=5)
    model_dtc = dtc.fit(X_train, y_train)
    preds_dtc = model_dtc.predict(X_test)
    print("Decision Tree Classifier: ",accuracy_score(y_test, preds_dtc),"com",i,"profundidade.")
# Out:
# Decision Tree Classifier:  0.6610169491525424 com 1 profundidade.
# Decision Tree Classifier:  0.7966101694915254 com 2 profundidade.
# Decision Tree Classifier:  0.8305084745762712 com 3 profundidade.
# Decision Tree Classifier:  0.864406779661017 com 4 profundidade.
# Decision Tree Classifier:  0.864406779661017 com 5 profundidade.

# %%
# Inicializando os classificadores
lr = LogisticRegression()
gnb = GaussianNB()
svc = SVC(kernel='poly',gamma=0.1,C=10)
knn = KNeighborsClassifier(n_neighbors=6,metric='euclidean')
dtc = DecisionTreeClassifier(criterion = "entropy", random_state = 100, max_depth=4, min_samples_leaf=5)

# %%
# Treinar os classificadores
model_lr = lr.fit(X_train, y_train)
model_gnb = gnb.fit(X_train, y_train)
model_svc = svc.fit(X_train, y_train)
model_knn = knn.fit(X_train, y_train)
model_dtc = dtc.fit(X_train, y_train)
# Out:
# C:\Users\mathe\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\mathe\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
# Fazer previsões para ter uma ideia do que o modelo determinou
preds_lr = model_lr.predict(X_test)
print("Logistic Regression: ",preds_lr)
preds_gnb = model_gnb.predict(X_test)
print("Gaussian: ",preds_gnb)
preds_svc = model_svc.predict(X_test)
print("SVC: ",preds_svc)
preds_knn = model_knn.predict(X_test)
print("K Neighbors Classifier: ",preds_knn)
preds_dtc = model_dtc.predict(X_test)
print("Decision Tree Classifier: ",preds_dtc)
# Out:
# Logistic Regression:  [1 3 3 1 2 1 2 3 2 3 2 3 1 2 1 2 2 3 1 2 3 2 1 3 3 3 3 1 2 1 2 2 3 2 1 3 3
#  3 2 1 3 2 2 2 3 1 2 3 1 1 2 1 2 3 2 2 2 2 2]
# Gaussian:  [1 1 3 1 2 1 2 3 2 1 2 3 1 2 1 3 2 3 1 2 1 1 3 3 3 3 2 1 2 1 1 2 3 2 1 3 3
#  3 2 3 1 2 2 2 3 1 2 3 3 1 2 1 1 3 3 2 3 1 2]
# SVC:  [1 1 3 1 2 1 2 3 2 3 2 3 1 2 1 2 2 3 1 2 1 2 1 3 3 1 2 1 2 1 1 2 3 1 1 1 3
#  3 2 3 1 2 2 2 3 1 2 2 3 1 2 1 1 3 2 2 2 1 2]
# K Neighbors Classifier:  [1 1 3 1 2 1 2 3 2 3 2 3 1 2 1 1 2 3 1 2 1 1 1 3 3 3 1 1 2 1 1 2 3 2 1 1 3
#  3 2 3 1 2 2 2 1 1 2 2 1 1 2 1 1 3 2 2 2 2 2]
# Decision Tree Classifier:  [1 1 3 1 2 1 2 3 2 1 2 3 1 2 1 3 2 3 1 2 1 2 1 3 3 3 2 2 2 1 2 2 3 1 1 1 3
#  3 2 2 1 2 2 2 3 1 2 2 2 1 2 1 1 3 2 2 2 1 2]

# %%
# Avaliar a acurácia
print("Logistic Regression: ",accuracy_score(y_test, preds_lr))
print("Gaussian: ",accuracy_score(y_test, preds_gnb))
print("SVC: ",accuracy_score(y_test, preds_svc))
print("K Neighbors Classifier: ",accuracy_score(y_test, preds_knn))
print("Decision Tree Classifier: ",accuracy_score(y_test, preds_dtc))
# Out:
# Logistic Regression:  0.7288135593220338
# Gaussian:  0.7966101694915254
# SVC:  0.9152542372881356
# K Neighbors Classifier:  0.8135593220338984
# Decision Tree Classifier:  0.864406779661017

# %%
# Precisão, recall e f-measure (com micro, macro e weighted average)
print("Logistic Regression: ")
target_names = ['Class 1', 'Class 2', 'Class 3']
print(classification_report(y_test, preds_lr, target_names=target_names))
print("Gaussian: ")
print(classification_report(y_test, preds_gnb, target_names=target_names))
print("SVC: ")
print(classification_report(y_test, preds_svc, target_names=target_names))
print("K Neighbors Classifier: ")
print(classification_report(y_test, preds_knn, target_names=target_names))
print("Decision Tree Classifier: ")
print(classification_report(y_test, preds_dtc, target_names=target_names))
# Out:
# Logistic Regression:
#               precision    recall  f1-score   support
#
#      Class 1       0.73      0.55      0.63        20
#      Class 2       0.80      0.80      0.80        25
#      Class 3       0.63      0.86      0.73        14
#
#    micro avg       0.73      0.73      0.73        59
#    macro avg       0.72      0.74      0.72        59
# weighted avg       0.74      0.73      0.72        59
#
# Gaussian:
#               precision    recall  f1-score   support
#
#      Class 1       0.85      0.85      0.85        20
#      Class 2       0.89      0.68      0.77        25
#      Class 3       0.65      0.93      0.76        14
#
#    micro avg       0.80      0.80      0.80        59
#    macro avg       0.80      0.82      0.80        59
# weighted avg       0.82      0.80      0.80        59
#
# SVC:
#               precision    recall  f1-score   support
#
#      Class 1       0.86      0.95      0.90        20
#      Class 2       0.96      0.88      0.92        25
#      Class 3       0.93      0.93      0.93        14
#
#    micro avg       0.92      0.92      0.92        59
#    macro avg       0.92      0.92      0.92        59
# weighted avg       0.92      0.92      0.92        59
#
# K Neighbors Classifier:
#               precision    recall  f1-score   support
#
#      Class 1       0.71      0.85      0.77        20
#      Class 2       0.86      0.76      0.81        25
#      Class 3       0.92      0.86      0.89        14
#
#    micro avg       0.81      0.81      0.81        59
#    macro avg       0.83      0.82      0.82        59
# weighted avg       0.83      0.81      0.82        59
#
# Decision Tree Classifier:
#               precision    recall  f1-score   support
#
#      Class 1       0.90      0.90      0.90        20
#      Class 2       0.85      0.88      0.86        25
#      Class 3       0.85      0.79      0.81        14
#
#    micro avg       0.86      0.86      0.86        59
#    macro avg       0.86      0.86      0.86        59
# weighted avg       0.86      0.86      0.86        59

# %%
#Índice Kappa
print("Logistic Regression: ")
print(cohen_kappa_score(y_test, preds_lr),"\n")
print("Gaussian: ")
print(cohen_kappa_score(y_test, preds_gnb),"\n")
print("SVC: ")
print(cohen_kappa_score(y_test, preds_svc),"\n")
print("K Neighbors Classifier: ")
print(cohen_kappa_score(y_test, preds_knn),"\n")
print("Decision Tree Classifier: ")
print(cohen_kappa_score(y_test, preds_dtc),"\n")
# Out:
# Logistic Regression:
# 0.5877729257641922
#
# Gaussian:
# 0.6956147893379192
#
# SVC:
# 0.8700440528634361
#
# K Neighbors Classifier:
# 0.7139709122961657
#
# Decision Tree Classifier:
# 0.7901289461983103

# %%
#Curva ROC

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_lr))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Logistic Regression - WINE DATASET')
plt.legend(loc="lower right")
plt.show()

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_gnb))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for GaussianNB - WINE DATASET')
plt.legend(loc="lower right")
plt.show()

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_svc))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for SVC - WINE DATASET')
plt.legend(loc="lower right")
plt.show()

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_knn))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for K Neighbors Classifier - WINE DATASET')
plt.legend(loc="lower right")
plt.show()

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array(pd.get_dummies(y_test))[:, i], np.array(pd.get_dummies(preds_dtc))[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

lw=2
plt.figure(figsize=(8,5))
plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='green', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--',color='red', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.annotate('Random Guess',(.5,.48),color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Decision Tree Classifier - WINE DATASET')
plt.legend(loc="lower right")
plt.show()
